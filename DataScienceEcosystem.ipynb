# %% [markdown]
# ![image.png](attachment:5b0405d2-0647-43c0-935e-7f06812de89e.png)

# %% [markdown]
# ![image.png](attachment:19fffd66-b8a6-42dd-ab5d-567668f2c8e5.png)

# %% [markdown]
# # Heading

# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# # Kritika Bhardwaj

# %% [markdown]
# Hi, I am B.Tech Student of Medi-Caps University. In this notebook, Data Science Tools and Ecosystem, I am going to show all exercises which is provided by IBM specialist for completing my certification and for my knowledge gain.

# %% [markdown]
# # Popular Languages

# %% [markdown]
# Some of the Popular languages of Data Science are:
# * Python
# * R
# * SQL
# * JavaScript
# * Scala
# * Julia

# %% [markdown]
# # Libraries

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# * Pandas
# * TensorFlow
# * Matplotlib
# * NumPy
# * SciPy
# * PyTorch
# * Keras
# * Scrapy

# %% [markdown]
# # Table

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Rstudio           |
# |Apache Spark      |
# |TensorFlow        |

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
12+3
# Out:
# 15

# %%
12-3
# Out:
# 9

# %%
12/4
# Out:
# 3.0

# %%
12*4
# Out:
# 48

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minute = 200
hrs = minute / 60
print(hrs)
# Out:
# 3.3333333333333335

# %% [markdown]
# # Objectives

# %% [markdown]
# <h3>List popular languages for Data Science</h3>

# %% [markdown]
# * Python
# * SQL
# * JavaScript
# * R
# * Scala

# %% [markdown]
# <h2> Author </h2>
# Kritika Bhardwaj
